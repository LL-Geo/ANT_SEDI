# %%
import seaborn as sns
import scipy.io as sio
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import math

from matplotlib import rcParams
from matplotlib.patches import Rectangle
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

sns.set_style('whitegrid', {'xtick.color': '.15',
 'xtick.direction': u'in',
 'xtick.major.size': 10,
 'xtick.minor.size': 1,
 'ytick.color': '.15',
 'ytick.direction': u'in',
 'ytick.major.size': 10,
 'ytick.minor.size': 0.1,
 'grid.color': '.8',
 'axes.edgecolor': '.4',
 'grid.linestyle': u'--',
 'axes.linewidth': 1.0,
 'grid.linewidth': 0.5})

SMALL_SIZE = 20
MEDIUM_SIZE = 20
BIGGER_SIZE = 20

plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=BIGGER_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

paired = sns.color_palette("Set1", 9)
paired2 = sns.color_palette("Paired", 9)
paired3 = sns.color_palette("Set3", 9)

# %%
ice_thin=sio.loadmat('./icethin')

# %%
f = plt.figure()
f.set_size_inches(7,7)
plt.rc('axes', axisbelow=False)
plt.subplots_adjust(hspace=0)
plt.subplots_adjust(wspace=0)

a=ice_thin['a']
a= a[~np.isnan(a)]
b=ice_thin['b']
b= b[~np.isnan(b)]
bo=ice_thin['bo']
bo= bo[~np.isnan(bo)]
ao=ice_thin['ao']
ao= ao[~np.isnan(ao)]

plt.errorbar(a/100, b,xerr=ao/100,yerr=bo, fmt='ko',mec='k',markersize=5)

plt.plot(ice_thin['Result'][0:5,0]/100,ice_thin['Result'][0:5,1], 'bx',markersize=10)
plt.plot(ice_thin['Result'][6,0]/100,ice_thin['Result'][6,1], 'bx',markersize=10)
plt.plot(ice_thin['Result'][8,0]/100,ice_thin['Result'][8,1], 'bx',markersize=10)
plt.plot(ice_thin['Result'][9,0]/100,ice_thin['Result'][9,1], 'bx',markersize=10)

plt.plot([0.8, -3.5], [88, -385], 'r', lw=2)
#plt.plot([-3.5, -10], [-385, -1100], 'r--', lw=2)

plt.plot([-3.5, -3.5], [-550, 100], 'k:', lw=2)
plt.plot([-3.5, 1], [-550, -550], 'k:', lw=2)

plt.xlim([-9.5,0.8])
plt.ylim([-1350,100])

plt.xticks(np.arange(-9, 0.5, 1),fontsize=7)
plt.yticks(np.arange(-1300, 100, 100),fontsize=7)

plt.xlabel(r'Surface elevation rate of change $(m a^{-1})$ ',fontsize=7)
plt.ylabel(r'Grounding-line migration rate $(m a^{-1})$  ',fontsize=7)

plt.text(-2.81,-318.1,'Thwaites\n Glacier',fontsize=7)
plt.text(-2.26,-153.6,'Totten\n Glacier',fontsize=7)
plt.text(-1.08,-65.2,'PIG',fontsize=7)

#f.savefig("e_1.jpg",dpi=300) #save as jpg
# Out:
# Text(-1.08, -65.2, 'PIG')
